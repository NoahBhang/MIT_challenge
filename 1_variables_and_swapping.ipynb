# %%
print("hello Jupyter!")
meters = 100
feet = 3.2808 * meters
feet
meters = 200
feet

feet
#왜 feet가 그대로 328.08이 되냐면 feet는 처음 변수 meters = 100 으로 계산한 결과 값이고, 다음에 새롭게 만든 변수 meters = 200은 전에 만들어진 feet에 반영되지 않았기 때문이다. 즉, 자동으로 반영되는 게 아니고 시간 순에 따라 반영된다.
x = 1
y = 2
temp = 2
x = temp
y = x - 1
print(x)
print(y)
# Out:
# hello Jupyter!
# 2
# 1
