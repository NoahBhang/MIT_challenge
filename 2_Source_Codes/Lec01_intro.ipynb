# %% [markdown]
# ### 콘솔 안에 있는 객체의 타입을 확인하는 확인하는 법
#
#
# #### type을 선언하고 괄호( ) 안에 알고자 하는 인수를 넣는다.

# %%
type(5)
# Out:
# int

# %%
type(3.0)
# Out:
# float

# %% [markdown]
# ### 다른 타입으로 전환
# #### 부동소수점, 정수, 반올림

# %%
float(3)
# Out:
# 3.0

# %%
int(3.9)
# Out:
# 3

# %%
round(3.9)
# Out:
# 4

# %% [markdown]
# ### 표현식

# %%
3+2
# Out:
# 5

# %%
(4+2)*6-1
# Out:
# 35

# %%
type((4+2)*6-1)
# Out:
# int

# %%
float((4+2)*6-1)
# Out:
# 35.0

# %% [markdown]
# ### 변수 선언
# ####    Pi를 위한 어림값 계산/  반지름/  넓이/ 원의둘레길이

# %%
pi = 355/133
radius = 2.2
area = pi*(radius**2)
circumference = pi*(radius*2)

# %% [markdown]
# ### 코드 형식
# #### Example 1

# %%
a = 355/113 * (2.2**2)

# %%
c = 355/113 *(2.2*2)

# %% [markdown]
# #### Example 2

# %%
p = 355/133
r = 2.2
# multiply p with r squared
a = p*(r**2)
# multiply p with r times
c = p*(r*2)

# %% [markdown]
# #### Example3
# ##### 파이를 활용하여 원의 둘레길이 계산하기

# %%
pi = 355/133
radius = 2.2
area = pi*(radius**2)
circumference = pi*(radius**2)

# %% [markdown]
# #### 연결 변경(Changing Bindings)

# %%
pi = 3.14
radius = 2.2
area = pi*(radius**2)
radius = radius +1

# %% [markdown]
# #### 오류 수정-값의 맞교환, 덮어쓰기의 오류
# ##### 아래 변수 x와 y가 있다. 잘못된 맞교환이 있다. 수정하라!

# %%
x = 1
y = 2
# Buggy example
y = x
x = y
# Fix it here!

# 1.제 3의 변수를 사용해서 푸는 법 = 사물함에 물건을 잠시 옮겨두기
x = 1
y = 2
z = x
x = y
y = x
# 2. 순수하게 더하기와 빼기 연산만으로 맞교환하기
x = 1
y = 2

x = x+y # x는 3. 두 수의 합
y = x-y # Y는 1. y에 원래의 x값이 저장됨
x = x-y

# 결과: x = 2, y = 1

# %% [markdown]
# ##### 파이썬에서는 임시 변수 없이 한 줄로 안전하게 맞교환이 가능하다.

# %%
x = 1
y = 2

x,y = y,x

# %%
y+0
# Out:
# 1

# %%
x+0
# Out:
# 2
